# %%
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
from sklearn import datasets

# %%
df = datasets.load_diabetes()

# %%
dir(df)
# Out:
# ['DESCR',
#  'data',
#  'data_filename',
#  'data_module',
#  'feature_names',
#  'frame',
#  'target',
#  'target_filename']

# %%
import pandas as pd

# %%
f = pd.DataFrame(data = df['data'],columns=df['feature_names'])
f['dep'] = df['target']
f
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6    dep
# ...

# %%
y=f['dep']
X=f.drop('dep',axis=1)
print(X.head())
print(y.head())
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# Name: dep, dtype: float64

# %%
X_train,X_test,y_train,y_test = sklearn.model_selection.train_test_split(X,y,test_size=.3,random_state=1)
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 332  0.030811 -0.044642  0.104809  0.076958 -0.011201 -0.011335 -0.058127
# 307  0.067136  0.050680 -0.030996  0.004658  0.024574  0.035638 -0.028674
# 328 -0.038207 -0.044642  0.067085 -0.060756 -0.029088 -0.023234 -0.010266
# 275 -0.005515  0.050680 -0.011595  0.011544 -0.022208 -0.015406 -0.021311
# 414  0.081666  0.050680  0.006728 -0.004534  0.109883  0.117056 -0.032356
# ..        ...       ...       ...       ...       ...       ...       ...
# 255  0.001751 -0.044642 -0.065486 -0.005670 -0.007073 -0.019476  0.041277
# 72   0.063504  0.050680 -0.004050 -0.012556  0.103003  0.048790  0.056003
# 396 -0.085430  0.050680 -0.030996 -0.022885 -0.063487 -0.054236  0.019187
# 235  0.067136  0.050680 -0.014828  0.058608 -0.059359 -0.034508 -0.061809
# 37  -0.009147 -0.044642  0.011039 -0.057313 -0.024960 -0.042963  0.030232
#
#            s4        s5        s6
# 332  0.034309  0.057108  0.036201
# ...

# %%
y_train
# Out:
# 332    270.0
# 307    172.0
# 328     78.0
# 275     94.0
# 414    131.0
#        ...
# 255    153.0
# 72     202.0
# 396     43.0
# 235    124.0
# 37     276.0
# Name: dep, Length: 309, dtype: float64

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (309, 10)
# (309,)
# (133, 10)
# (133,)

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lm.predict(X_train)
y_test_pred=lm.predict(X_test)

# %%
sf=pd.DataFrame([[y_train,y_train_pred]])
sf.head()
# Out:
#                                                    0  \
# 0  332    270.0
# 307    172.0
# 328     78.0
# 275    ...
#
#                                                    1
# 0  [294.509741987711, 142.4549664600904, 189.9575...

# %%
mse=mean_squared_error(y_test,y_test_pred)
print(mse)
# Out:
# 2827.084017424082

# %%
plt.scatter(y_train,y_train_pred,marker='o',color='blue',label='Training data')
plt.scatter(y_test,y_test_pred,marker='*',color='red',label='Testing data')
plt.xlabel('Predicted values')
plt.ylabel('True values')
plt.legend(loc='upper left')
plt.plot()
plt.show()

# %%
#Accuracy
from sklearn.metrics import r2_score

# %%
#training data Accuracy
r2_score(y_train,y_train_pred)
# Out:
# 0.5417924056813228

# %%
#Testing data Accuracy
r2_score(y_test,y_test_pred)
# Out:
# 0.43845439143447806

# %% [markdown]
# **Training Data**
#
# 'Actual Values and Predicted values and differences blw the two variables of actual and predicted and Accuracy %'

# %%
df=pd.DataFrame()
df['y_train']=y_train
df['y_train_pred']=y_train_pred
df['Loss']=y_train-y_train_pred
df['Accuracy in percentage %']=r2_score(y_train,y_train_pred)*100
df
# Out:
#      y_train  y_train_pred        Loss  Accuracy in percentage %
# 332    270.0    294.509742  -24.509742                 54.179241
# 307    172.0    142.454966   29.545034                 54.179241
# 328     78.0    189.957506 -111.957506                 54.179241
# 275     94.0    153.839772  -59.839772                 54.179241
# 414    131.0    163.145026  -32.145026                 54.179241
# ..       ...           ...         ...                       ...
# 255    153.0    113.154566   39.845434                 54.179241
# 72     202.0    141.573051   60.426949                 54.179241
# 396     43.0     64.641616  -21.641616                 54.179241
# 235    124.0    172.838854  -48.838854                 54.179241
# 37     276.0    155.523402  120.476598                 54.179241
#
# [309 rows x 4 columns]

# %% [markdown]
# **Testing Data**
#
# 'Actual value and predicted values and loss and Accuracy %'

# %%
df=pd.DataFrame()
df['y_test']=y_test
df['y_test_pred']=y_test_pred
df['Loss']=y_test-y_test_pred
df['Accuracy in percentage %']=r2_score(y_test,y_test_pred)*100
df
# Out:
#      y_test  y_test_pred        Loss  Accuracy in percentage %
# 246    78.0   117.359587  -39.359587                 43.845439
# 425   152.0   107.589492   44.410508                 43.845439
# 293   200.0   186.612242   13.387758                 43.845439
# 31     59.0    65.022655   -6.022655                 43.845439
# 359   311.0   172.786173  138.213827                 43.845439
# ..      ...          ...         ...                       ...
# 340   216.0   172.926666   43.073334                 43.845439
# 39     90.0   133.469410  -43.469410                 43.845439
# 191   178.0   120.763426   57.236574                 43.845439
# 320   122.0   192.165442  -70.165442                 43.845439
# 98     92.0   122.217749  -30.217749                 43.845439
#
# [133 rows x 4 columns]
